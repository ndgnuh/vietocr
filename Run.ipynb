# %%
from vietocr.tool.config import get_config, list_configs
from vietocr.tool.predictor import Predictor
from vietocr import sample_images
from PIL import Image
from matplotlib import pyplot as plt

# %%
configs = list_configs()
print(configs)
# Out:
# ['inception', 'vgg_transformer', 'vgg_seq2seq']

# %%
config = get_config(configs[0])
predictor = Predictor(config)
# Out:
# /usr/local/lib/python3.9/site-packages/torchvision/models/inception.py:43: FutureWarning: The default weight initialization of inception_v3 will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   warnings.warn(
# VietOCR(
#   (cnn): CNN(
#     (model): PatchedInception(
#       (inception): Sequential(
#         (Conv2d_1a_3x3): BasicConv2d(
#           (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (Conv2d_2a_3x3): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (Conv2d_2b_3x3): BasicConv2d(
# ...

# %%
for image in sample_images:
    image = Image.open(image)
    output = predictor(image)
    plt.imshow(image)
    plt.title(output[0])
    plt.show()

# %%
# # root = "vietocr/tests/image/"
# count = 0
# for image in shuffle(os.listdir(root)):
#     try:
#         image = Image.open(os.path.join(root, image))
#     except Exception:
#         continue
#     output = predictor(image)
#     plt.imshow(image)
#     plt.title(output[0])
#     plt.show()
#     count += 1
#     if count > 10:
#         break

# %%
image = Image.open("vietocr/tests/image/026301003919.jpeg")
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=342x38>

# %%
# Out:
# ['NCu êu VAN Biun']
